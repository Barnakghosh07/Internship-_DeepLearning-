# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense

# Load the IMDB movie review dataset
max_features = 10000  # Maximum number of words to include in the vocabulary
max_len = 500  # Maximum length of a review (in terms of number of words)
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# Pad sequences to have the same length
x_train = sequence.pad_sequences(x_train, maxlen=max_len)
x_test = sequence.pad_sequences(x_test, maxlen=max_len)

# Define the CNN model
model = Sequential()
model.add(Embedding(max_features, 128, input_length=max_len))
model.add(Conv1D(64, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, batch_size=32, epochs=5, validation_data=(x_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step
# Epoch 1/5
# 782/782 [==============================] - 153s 193ms/step - loss: 0.3735 - accuracy: 0.8202 - val_loss: 0.2680 - val_accuracy: 0.8912
# Epoch 2/5
# 782/782 [==============================] - 129s 165ms/step - loss: 0.1370 - accuracy: 0.9515 - val_loss: 0.2777 - val_accuracy: 0.8907
# Epoch 3/5
# 782/782 [==============================] - 128s 163ms/step - loss: 0.0264 - accuracy: 0.9936 - val_loss: 0.3459 - val_accuracy: 0.8938
# Epoch 4/5
# 782/782 [==============================] - 129s 165ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.3849 - val_accuracy: 0.8962
# Epoch 5/5
# 782/782 [==============================] - 148s 189ms/step - loss: 9.4170e-04 - accuracy: 0.9999 - val_loss: 0.4141 - val_accuracy: 0.8970
# 782/782 [==============================] - 24s 31ms/step - loss: 0.4141 - accuracy: 0.8970
# Test Loss: 0.4141
# Test Accuracy: 0.8970
